# %%
import numpy as np

# %%
r = np.double(input("r:"))
A = r**2 * 3.14
print(f"Area of the circle with radius {r} is {A}")
# Out:
# Area of the circle with radius 6.0 is 113.04

# %%
print(f"The type of r is {type(r)} and the type of A is {type(A)}")
# Out:
# The type of r is <class 'numpy.float64'> and the type of A is <class 'numpy.float64'>
